# %%
import pandas as pd
import numpy as np
import plotly.express as px

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV

from sklearn.linear_model import Lasso, LogisticRegression

# %%
data_merge = pd.read_excel('/content/drive/MyDrive/big_merge_V2_meteo_SAT.xlsx', sheet_name='Sheet1')

# %%
data_merge.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# Target definition :

# %%
TARGET =  'NIV_DEV'

# %%
fig = px.histogram(data_merge[TARGET], nbins=100)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="15e3860b-92f6-4aa2-bca9-387588c61dc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15e3860b-92f6-4aa2-bca9-387588c61dc8")) {                    Plotly.newPlot(                        "15e3860b-92f6-4aa2-bca9-387588c61dc8",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=NIV_DEV<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"NIV_DEV","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"NIV_DEV","nbinsx":100,"offsetgroup":"NIV_DEV","orientation":"v","showlegend":true,"x":[3,3,4,4,5,5,5,5,4,4,5,5,2,1,1,2,5,2,5,5,4,3,4,4,4,5,5,6,3,3,5,6,4,4,4,1,-1,6,4,4,4,3,4,4,4,4,2,2,3,3,4,4,4,3,5,3,3,6,4,5,3,2,2,3,1,1,2,2,1,5,6,4,4,-1,3,5,1,3,2,2,5,6,4,6,1,1,2,2,3,4,3,4,-1,5,4,5,2,2,3,2,5,4,5,4,1,1,2,2,4,4,4,4,5,4,5,5,4,5,4,5,5,5,6,5,3,4,3,3,3,3,6,1,4,4,5,4,3,6,3,6,4,3,3,4,4,5,5,4,5,4,5,5,1,2,3,6,4,4,4,4,6,6,4,6,4,1,4,5,6,6,3,6,3,4,4,3,2,2,3,1,3,6,3,6,1,2,1,2,6,4,3,4,6,3,6,4,1,5,5,5,1,6,5,6,4,4,4,4,4,3,4,3,5,4,5,4,3,4,3,6,4,5,4,4,4,4,3,4,2,3,6,6,2,5,4,6,4,3,3,3,3,3,2,2,4,5,5,5,1,2,2,2,2,1,1,1,4,-1,4,6,3,2,4,2,2,6,2,6,3,3,3,6,3,2,3,3,6,5,6,2,2,2,2,2,3,4,3,4,6,5,6,6,5,4,4,4,5,4,4,3,4,5,4,4,3,3,2,4,5,4,4,4,5,5,5,5,2,2,6,2,4,4,5,4,4,3,4,4,3,3,3,2,2,2,2,2,6,3,4,6,4,4,3,4,4,4,4,4,6,6,2,4,2,2,3,3,1,5,5,5,6,4,3,2,3,4,4,3,3,5,5,4,4,4,3,3,5,5,5,5,4,4,4,4,5,4,5,4,3,3,2,3,4,4,4,2,4,4,1,4,3,6,5,6,3,4,3,4,3,3,3,3,6,6,-1,5,4,4,4,5,3,4,3,3,4,4,6,3,5,6,4,6,4,-1,4,4,6,1,1,4,4,5,5,5,5,6,5,3,6,5,4,5,4,3,4,4,4,3,4,3,3,4,4,6,6,4,5,4,6,5,6,5,4,4,4,3,3,4,4,5,6,5,5,4,3,4,3,4,4,4,5,4,2,1,2,2,3,4,4,6,4,4,4,4,3,3,4,4,4,5,4,4,3,4,3,4,6,4,3,4,3,3,2,2,5,5,5,5,3,5,4,3,4,3,4,6,6,-1,6,4,6,6,3,3,4,4,4,4,3,-1,3,4,3,5,4,5,3,2,3,3,4,6,6,4,4,5,4,4,4,5,4,5,6,2,1,1,3,6,4,3,4,6,6,4,3,3,3,4,5,5,5,6,5,1,5,5,-1,6,4,5,5,4,4,5,4,3,3,3,6,3,6,2,4,4,5,3,1,5,5,1,3,3,6,4,4,3,3,3,4,3,3,5,6,6,5,5,4,4,5,4,3,6,3,2,4,4,3,3,2,3,3,3,6,6,-1,3,3,3,2,3,3,3,4,4,4,3,6,6,4,4,4,5,5,6,5,5,3,4,3,3,2,6,6,5,6,4,4,3,2,2,2,2,4,3,4,4,5,5,5,6,4,4,3,3,4,4,4,3,6,4,6,3,5,5,5,5,5,4,5,5,4,6,6,6,3,2,5,2,5,4,5,5,5,6,6,5,2,2,2,2,3,3,4,3,6,6,5,6,4,4,4,5,2,2,5,3,1,6,3,-1,4,4,5,4,4,4,5,5,4,4,6,4,5,-1,5,5,4,4,4,4,4,4,4,5,1,1,5,5,3,4,6,3,1,2,2,2,4,5,5,4,2,6,3,4,3,3,6,6,3,3,4,4,6,6,5,4,6,3,6,2,4,4,4,6,5,5,5,4,2,2,2,1,4,5,4,4,5,4,3,4,4,6,5,4,3,3,3,3,6,3,4,3,5,5,5,4,3,4,3,3,4,6,6,4,6,6,6,6,6,3,6,3,6,2,-1,3,6,3,6,3,4,4,5,4,3,5,4,4,5,5,-1,5,4,3,3,4,2,4,3,6,4,4,5,4,2,1,2,2,2,2,2,2,4,4,5,4,4,6,3,3,2,2,6,2,4,6,4,4,1,5,2,2,5,5,5,5,4,4,-1,5,5,4,4,5,5,5,6,5,4,3,4,4,5,5,-1,4,2,3,3,2,1,2,2,1,4,5,4,5,4,4,4,4,4,4,4,3,4,4,5,4,2,1,1,-1,4,6,3,6,6,6,5,5,5,5,5,5,2,2,2,6,6,6,5,3,3,6,4,4,6,4,5,4,4,4,-1,5,5,5,5,5,4,4,4,4,2,1,2,1,3,4,4,4,2,2,2,2,6,4,3,4,6,5,4,5,4,4,4,4,5,4,5,6,5,4,5,5,4,5,5,5,5,5,5,5,6,5,5,6,4,4,4,6,3,3,3,3,3,4,3,2,4,4,4,4,2,4,3,3,4,1,1,1,4,5,4,4,6,3,6,6,4,5,5,5,6,5,5,4,6,2,1,1,4,4,4,4,3,4,4,3,3,3,3,2,2,3,2,3,6,4,4,6,5,4,4,5,5,5,5,5,3,4,4,3,6,6,6,4,6,5,5,4,4,3,4,4,-1,4,5,3,5,5,4,5,2,4,3,2,5,5,5,5,4,6,6,4,2,2,2,6,4,3,3,6,3,2,3,2,3,4,4,4,2,3,3,3,2,6,4,4,4,2,2,4,5,4,4,4,2,-1,1,2,6,6,6,6,6,6,6,6,6,6,3,6,5,3,4,3,3,2,3,2,2,-1,1,1,5,5,4,4,4,5,6,4,4,4,5,5,5,4,3,3,5,5,4,3,5,5,5,1,3,2,2,4,6,6,5,5,1,3,4,4,4,4,3,3,6,6,6,6,4,4,3,4,1,2,2,2,3,3,6,3,6,5,6,5,6,1,4,2,6,4,4,6,2,4,4,3,4,1,3,2,1,5,1,5,-1,5,5,5,1,2,5,1,4,6,6,4,4,3,6,4,5,5,5,6,3,2,3,2,1,3,4,5,3,4,4,4,2,2,3,3,3,3,5,4,3,6,6,6,2,6,6,2,1,6,2,1,3,2,2,3,2,2,4,2,6,6,6,6,4,6,5,4,5,5,5,5,4,5,5,5,3,5,5,4,6,5,4,6,5,5,5,5,4,6,6,6,4,6,4,6,4,4,5,5,6,4,4,4,5,4,4,5,2,2,1,1,3,4,4,4,2,6,2,2,5,5,5,5,6,6,2,6,4,4,3,4,5,6,6,5,5,5,6,5,1,2,2,1,3,4,4,4,1,2,4,1,5,1,5,5,5,5,6,5,4,4,1,-1,5,4,5,3,2,2,2,2,3,3,3,3,5,5,5,5,5,5,5,6,4,6,1,4,3,4,6,3,-1,4,1,2,5,5,5,5,2,1,2,5,2,4,4,4,4,4,6,4,4,5,5,4,2,3,3,3,2,4,6,4,1,1,2,2,4,3,-1,-1,2,6,3,2,1,2,1,1,1,-1,4,3,4,4,4,4,4,3,6,4,5 ...

# %%
data_red = data_merge.loc[data_merge[TARGET]!=np.nan,:]
data_red = data_red.loc[data_merge[TARGET]!='NaN',:]
data_red = data_red.loc[data_merge[TARGET]!=-1,:]

# %%
len(data_red)
# Out:
# 9364

# %%
Y = data_red[TARGET]

# %%
Y
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       5
#        ..
# 9607    4
# 9608    5
# 9609    3
# 9610    5
# 9611    5
# Name: NIV_DEV, Length: 9364, dtype: int64

# %% [markdown]
# Particular preprocessing for features :

# %%
data_red['LFI'] = data_red['LFI'].map({'LFI1':1,
                                       'LFI2':2,
                                       'LFI3':3,
                                       'LFI4':4})

# %% [markdown]
# preprocess LFI

# %% [markdown]
# Selection of features :

# %%
targets_cat__ord_feat = ['DEGRAD_PPL'] # enlever :

# %%
targets_numeric_feat = ['PERF_CROI', '25_GRID_PER', 'UNIT_VOL_BOIS_MANQUANT', 'SURF_TER_HA', 'TAUX_COUV_RAJ', 'UNIT_ACCR'] #

# %%
cat_strict = ['PRODREG','UNIT_VEG_GROS','MODE_REGEN','INTENSITE_EXPLOIT','TRACES_FEU','RELIEF','DEG_FERMETURE','STR_PPL', 'TYPE_FORET305', 'TYP_RAJ_PPL','TAUX_COUV_RAJ_ASS', 'ESPECE_DOM', 'TYPE_FORET'] # enlevé : , 'NIV_DEV'

# %%
cat_ord_miss = ['TAILLE_PPL', 'MELANGE', 'HT_VEG', 'LFI'] # enlever :

# %%
numerical = ['ALT','SLOPE25','QUAL_STATION','AGE_PPL','DIV_STR_PPL','DDOM','TIGES_VIV_H', 'EPIC_PER',	'SAPIN_PER', 'PIN_PER', 'MELEZ_PER'	,'ARO_PER', 'OTHER_CONIF_PER'	,'HETR_PER' ,'ERAB_PER', 'FREN_PER', 'CHEN_PER', 'DGANTCA', 'OTHER_FEUILL_PER',	'CONIF_PER_STD', 'ARBUST_PER', 'FEUILL_PER', 'CONIF_PER', 'PROCESS_SILVA', 'V_ALL',	'V_FICHT', 'V_TANNE',	'V_FOEHR', 'V_LARCH',	'V_ARVEN', 'V_UENDH',	'V_BUCHE', 'V_AHORN',	'V_ESCHE',	'V_EICHE', 'V_CASTA',	'V_UELBH', 'DBH', 'HAUTEUR_ARBRE', 'AGE_ARBRE', 'PRCP', 'TAVE_AVG',	'TAVE', 'TAVE_GROWTH', 'PRCP_S_S',	'PRCP_G_S', 'NDVI', 'EVI', 'NDMI', 'NDWI', 'DSWI'] # enlever : 'SDI'

# %% [markdown]
# Preprocessing for cat_ord_miss :

# %%
for cat in cat_ord_miss:
  data_red[cat] = data_red[cat].apply(lambda v : v if v!=-1 else np.nan)

# %%
for cat in cat_ord_miss:
  print(data_red[cat].dtypes)
# Out:
# float64
# int64
# int64
# int64

# %%
numerics_feats = numerical + targets_numeric_feat + cat_ord_miss
categorical_feats = cat_strict + targets_cat__ord_feat

# %%
len(numerics_feats)
# Out:
# 61

# %%
len(categorical_feats)
# Out:
# 14

# %%
data_red = data_red[[cat for cat in numerics_feats + categorical_feats]]

# %%
numerics_transforms = Pipeline(
    [('imputer',KNNImputer()),
    ('encoder',StandardScaler())
])
categorials_transforms = Pipeline([
    ('imputer',KNNImputer()),
    ('encoder',OneHotEncoder(drop="first"))
])

preprocessor = ColumnTransformer(
    [("num", numerics_transforms, numerics_feats),
     ("cat", categorials_transforms, categorical_feats)])

# %%
X_train, X_test, y_train, y_test = train_test_split(data_red, Y, test_size=0.2, random_state=2)

# %%
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
np.shape(X_train)
# Out:
# (7491, 154)

# %%
model =  LogisticRegression(max_iter=10000)

# %%
params = {
    'C':[0.01, 0.05, 0.1]
}

# %%
grid = GridSearchCV(model, param_grid=params, scoring='r2', verbose=1)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(estimator=LogisticRegression(max_iter=10000),
#              param_grid={'C': [0.01, 0.05, 0.1]}, scoring='r2', verbose=1)

# %%
grid.best_estimator_
# Out:
# LogisticRegression(C=0.1, max_iter=10000)

# %%
y_pred = grid.best_estimator_.predict(X_train)
y_pred_test = grid.best_estimator_.predict(X_test)

# %%
r2_score(y_train, y_pred)
# Out:
# 0.8828277652954506

# %%
r2_score(y_test, y_pred_test)
# Out:
# 0.85596968736496

# %%
train_scores = cross_val_score(grid.best_estimator_, X_train, y_train, cv=5)
test_scores = cross_val_score(grid.best_estimator_, X_test, y_test, cv=5)
print(f'Train score mean : {np.mean(train_scores)}')
print(f'Train score std : {np.std(train_scores)}')
print(f'Test score mean : {np.mean(test_scores)}')
print(f'Test score std : {np.std(test_scores)}')
# Out:
# Train score mean : 0.9411289769503657
# Train score std : 0.005531248243912271
# Test score mean : 0.9369896613190731
# Test score std : 0.014730702088888057

# %%
len(grid.best_estimator_.coef_)
# Out:
# 6

# %%
list_features_in = []
for feat in numerics_feats:
  list_features_in.append(feat)
for cat in categorical_feats:
  nb_lab = len(data_red[cat].unique())-1
  for i in range(nb_lab):
    list_features_in.append(f'{cat}_{i}')

# %%
coeff_arr = pd.DataFrame(abs(grid.best_estimator_.coef_)).sum().to_numpy()

# %%
df_coef = pd.DataFrame(coeff_arr, index=list_features_in, columns=['Coeff'])

# %%
fig = px.bar(df_coef['Coeff'], title=f"Features importance for target : {TARGET} with Lasso Linear Regression")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d8cfb1b1-7fe4-4a89-8505-90a55d018618" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8cfb1b1-7fe4-4a89-8505-90a55d018618")) {                    Plotly.newPlot(                        "d8cfb1b1-7fe4-4a89-8505-90a55d018618",                        [{"alignmentgroup":"True","hovertemplate":"variable=Coeff<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Coeff","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Coeff","offsetgroup":"Coeff","orientation":"v","showlegend":true,"textposition":"auto","x":["ALT","SLOPE25","QUAL_STATION","AGE_PPL","DIV_STR_PPL","DDOM","TIGES_VIV_H","EPIC_PER","SAPIN_PER","PIN_PER","MELEZ_PER","ARO_PER","OTHER_CONIF_PER","HETR_PER","ERAB_PER","FREN_PER","CHEN_PER","DGANTCA","OTHER_FEUILL_PER","CONIF_PER_STD","ARBUST_PER","FEUILL_PER","CONIF_PER","PROCESS_SILVA","V_ALL","V_FICHT","V_TANNE","V_FOEHR","V_LARCH","V_ARVEN","V_UENDH","V_BUCHE","V_AHORN","V_ESCHE","V_EICHE","V_CASTA","V_UELBH","DBH","HAUTEUR_ARBRE","AGE_ARBRE","PRCP","TAVE_AVG","TAVE","TAVE_GROWTH","PRCP_S_S","PRCP_G_S","NDVI","EVI","NDMI","NDWI","DSWI","PERF_CROI","25_GRID_PER","UNIT_VOL_BOIS_MANQUANT","SURF_TER_HA","TAUX_COUV_RAJ","UNIT_ACCR","TAILLE_PPL","MELANGE","HT_VEG","LFI","PRODREG_0","PRODREG_1","PRODREG_2","PRODREG_3","UNIT_VEG_GROS_0","UNIT_VEG_GROS_1","UNIT_VEG_GROS_2","UNIT_VEG_GROS_3","UNIT_VEG_GROS_4","UNIT_VEG_GROS_5","UNIT_VEG_GROS_6","UNIT_VEG_GROS_7","UNIT_VEG_GROS_8","UNIT_VEG_GROS_9","UNIT_VEG_GROS_10","UNIT_VEG_GROS_11","UNIT_VEG_GROS_12","UNIT_VEG_GROS_13","UNIT_VEG_GROS_14","UNIT_VEG_GROS_15","UNIT_VEG_GROS_16","MODE_REGEN_0","MODE_REGEN_1","MODE_REGEN_2","MODE_REGEN_3","INTENSITE_EXPLOIT_0","INTENSITE_EXPLOIT_1","INTENSITE_EXPLOIT_2","TRACES_FEU_0","RELIEF_0","RELIEF_1","RELIEF_2","RELIEF_3","RELIEF_4","DEG_FERMETURE_0","DEG_FERMETURE_1","DEG_FERMETURE_2","DEG_FERMETURE_3","DEG_FERMETURE_4","DEG_FERMETURE_5","DEG_FERMETURE_6","DEG_FERMETURE_7","DEG_FERMETURE_8","DEG_FERMETURE_9","STR_PPL_0","STR_PPL_1","STR_PPL_2","TYPE_FORET305_0","TYPE_FORET305_1","TYPE_FORET305_2","TYPE_FORET305_3","TYPE_FORET305_4","TYPE_FORET305_5","TYPE_FORET305_6","TYPE_FORET305_7","TYPE_FORET305_8","TYPE_FORET305_9","TYPE_FORET305_10","TYPE_FORET305_11","TYPE_FORET305_12","TYP_RAJ_PPL_0","TYP_RAJ_PPL_1","TYP_RAJ_PPL_2","TAUX_COUV_RAJ_ASS_0","TAUX_COUV_RAJ_ASS_1","TAUX_COUV_RAJ_ASS_2","TAUX_COUV_RAJ_ASS_3","TAUX_COUV_RAJ_ASS_4","TAUX_COUV_RAJ_ASS_5","TAUX_COUV_RAJ_ASS_6","ESPECE_DOM_0","ESPECE_DOM_1","ESPECE_DOM_2","ESPECE_DOM_3","ESPECE_DOM_4","ESPECE_DOM_5","ESPECE_DOM_6","ESPECE_DOM_7","ESPECE_DOM_8","ESPECE_DOM_9","ESPECE_DOM_10","ESPECE_DOM_11","TYPE_FORET_0","TYPE_FORET_1","TYPE_FORET_2","TYPE_FORET_3","TYPE_FORET_4","DEGRAD_PPL_0","DEGRAD_PPL_1","DEGRAD_PPL_2","DEGRAD_PPL_3","DEGRAD_PPL_4","DEGRAD_PPL_5"],"xaxis":"x","y":[0.5061598716331605,0.22948764578978303,0.2230746193437185,5.365324448884552,2.362700721686872,1.4222223033978416,1.646756185244286,0.21381308897350326,0.3765549792198361,0.4581055540899228,0.33796171120175184,0.481836701400266,0.3219288356757755,0.8295526591650136,0.46874600077878553,0.15130199228249014,0.39975675434082736,0.14328946871876164,0.6023412678813607,0.23212354588782838,0.29965504423485706,0.24198928201248443,0.1768507421303583,0.33309244345051064,0.9532398733385878,0.7285755607832392,0.3128532432648664,0.36197985426754364,0.45357169127416147,0.33517534916539576,0.30251649866671926,0.49600167022732405,0.5770002393190313,0.35944599231018326,0.44968585149701523,0.6095703016361713,0.6879058397725726,0.8524081465161351,1.3365625551707248,0.5625998966461536,0.39823772103914135,0.4053477794219077,0.07587145991992437,0.4161449395790991,0.8492214178835769,0.5036716776296619,0.5613362029052591,0.3453444051 ...
